# %%
# by Sahar Sajadieh
# HW2-MAT201a-W15
# The program convert the image of a kitten into a helicopter sound effect
# %pylab inline
from __future__ import print_function
from __future__ import division
img = imread('kitten.jpg')
imshow(img)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import wave
from scipy.io import wavfile
sig = img[120,:, 1]
plot(sig)
sig.dtype
# Out:
# dtype('uint8')

# %%
sigout = list((sig.astype(int16) - 90) * 200)*30
plot(sigout)

# %%
audioout3 = array(((img[:,:,0].astype(int16)- 90) * 200).flat)
wavfile.write('helicopter.wav', 8000, audioout3)
